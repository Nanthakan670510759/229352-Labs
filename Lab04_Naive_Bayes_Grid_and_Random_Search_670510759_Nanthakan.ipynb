# %% [markdown]
# <a href="https://colab.research.google.com/github/Nanthakan670510759/229352-Labs/blob/main/Lab04_Naive_Bayes_Grid_and_Random_Search_670510759_Nanthakan.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Statistical Learning for Data Science 2 (229352)
# #### Instructor: Donlapark Ponnoprat
#
# #### [Course website](https://donlapark.pages.dev/229352/)
#
# ## Lab #4

# %%
from sklearn.datasets import fetch_20newsgroups
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics import classification_report
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV#สุ่มเลือกพารามิเต้อ

from sklearn.naive_bayes import MultinomialNB
from sklearn.pipeline import Pipeline

from scipy.stats import uniform

# %%
train = fetch_20newsgroups(subset='train')
test = fetch_20newsgroups(subset='test')

Xtrain = train.data[:3000]
ytrain = train.target[:3000]
Xtest = test.data[:500]
ytest = test.target[:500]

print("X:", len(Xtest))
print("y:", len(ytest))
# Out:
# X: 500
# y: 500

# %% [markdown]
# ### Naive Bayes [(Documentation)](https://scikit-learn.org/stable/modules/generated/sklearn.naive_bayes.MultinomialNB.html)

# %%
pipeline=Pipeline([('tfidf',TfidfVectorizer(stop_words='english')),('nb',MultinomialNB())])
pipeline.fit(Xtrain,ytrain)
ypred=pipeline.predict(Xtest)
print(classification_report(ytest,ypred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.67      0.38      0.48        21
#            1       0.79      0.52      0.63        21
#            2       0.58      0.69      0.63        26
#            3       0.74      0.68      0.71        34
#            4       0.72      0.85      0.78        34
#            5       0.88      0.81      0.84        26
#            6       1.00      0.73      0.84        22
#            7       0.70      1.00      0.82        28
#            8       0.90      0.82      0.86        33
#            9       0.88      0.84      0.86        25
#           10       0.82      1.00      0.90        27
#           11       0.79      0.95      0.86        20
#           12       0.59      0.54      0.57        24
#           13       0.75      0.78      0.77        23
#           14       0.87      0.71      0.78        28
#           15       0.53      0.90      0.67        29
#           16       0.50      0.95      0.66        21
#           17       0.94      0.83      0.88        18
#           18       0.86      0.23      0.36        26
#           19       0.00      0.00      0.00        14
#
#     accuracy                           0.73       500
#    macro avg       0.72      0.71      0.70       500
# weighted avg       0.74      0.73      0.71       500
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %% [markdown]
# ### Random Search Cross-Validation [(Documentation)](https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.RandomizedSearchCV.html)
#
# ### Uniform distribution in `Scipy` [(Documentation)](https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.uniform.html)

# %%
parameters={'nb__alpha':uniform(loc=0,scale=10)}
clf=RandomizedSearchCV(pipeline,parameters,n_iter=7,verbose=100)#สุ่มกี่ครั้ง
clf.fit(Xtrain,ytrain)
# Out:
# Fitting 5 folds for each of 7 candidates, totalling 35 fits
# [CV 1/5; 1/7] START nb__alpha=7.621556348267791.................................
# [CV 1/5; 1/7] END ..nb__alpha=7.621556348267791;, score=0.683 total time=   1.0s
# [CV 2/5; 1/7] START nb__alpha=7.621556348267791.................................
# [CV 2/5; 1/7] END ..nb__alpha=7.621556348267791;, score=0.668 total time=   1.4s
# [CV 3/5; 1/7] START nb__alpha=7.621556348267791.................................
# [CV 3/5; 1/7] END ..nb__alpha=7.621556348267791;, score=0.670 total time=   2.4s
# [CV 4/5; 1/7] START nb__alpha=7.621556348267791.................................
# [CV 4/5; 1/7] END ..nb__alpha=7.621556348267791;, score=0.652 total time=   2.2s
# [CV 5/5; 1/7] START nb__alpha=7.621556348267791.................................
# [CV 5/5; 1/7] END ..nb__alpha=7.621556348267791;, score=0.687 total time=   1.4s
# [CV 1/5; 2/7] START nb__alpha=3.855977560037356.................................
# [CV 1/5; 2/7] END ..nb__alpha=3.855977560037356;, score=0.743 total time=   0.9s
# [CV 2/5; 2/7] START nb__alpha=3.855977560037356.................................
# [CV 2/5; 2/7] END ..nb__alpha=3.855977560037356;, score=0.747 total time=   0.9s
# [CV 3/5; 2/7] START nb__alpha=3.855977560037356.................................
# [CV 3/5; 2/7] END ..nb__alpha=3.855977560037356;, score=0.737 total time=   0.8s
# [CV 4/5; 2/7] START nb__alpha=3.855977560037356.................................
# [CV 4/5; 2/7] END ..nb__alpha=3.855977560037356;, score=0.720 total time=   0.9s
# [CV 5/5; 2/7] START nb__alpha=3.855977560037356.................................
# [CV 5/5; 2/7] END ..nb__alpha=3.855977560037356;, score=0.753 total time=   0.9s
# [CV 1/5; 3/7] START nb__alpha=3.7526566242549753................................
# [CV 1/5; 3/7] END .nb__alpha=3.7526566242549753;, score=0.745 total time=   1.0s
# [CV 2/5; 3/7] START nb__alpha=3.7526566242549753................................
# [CV 2/5; 3/7] END .nb__alpha=3.7526566242549753;, score=0.750 total time=   1.4s
# [CV 3/5; 3/7] START nb__alpha=3.7526566242549753................................
# [CV 3/5; 3/7] END .nb__alpha=3.7526566242549753;, score=0.738 total time=   1.1s
# [CV 4/5; 3/7] START nb__alpha=3.7526566242549753................................
# [CV 4/5; 3/7] END .nb__alpha=3.7526566242549753;, score=0.722 total time=   0.9s
# [CV 5/5; 3/7] START nb__alpha=3.7526566242549753................................
# [CV 5/5; 3/7] END .nb__alpha=3.7526566242549753;, score=0.755 total time=   0.8s
# [CV 1/5; 4/7] START nb__alpha=0.9785536130829431................................
# [CV 1/5; 4/7] END .nb__alpha=0.9785536130829431;, score=0.797 total time=   0.9s
# [CV 2/5; 4/7] START nb__alpha=0.9785536130829431................................
# [CV 2/5; 4/7] END .nb__alpha=0.9785536130829431;, score=0.822 total time=   0.8s
# [CV 3/5; 4/7] START nb__alpha=0.9785536130829431................................
# [CV 3/5; 4/7] END .nb__alpha=0.9785536130829431;, score=0.795 total time=   0.8s
# [CV 4/5; 4/7] START nb__alpha=0.9785536130829431................................
# [CV 4/5; 4/7] END .nb__alpha=0.9785536130829431;, score=0.792 total time=   0.8s
# [CV 5/5; 4/7] START nb__alpha=0.9785536130829431................................
# [CV 5/5; 4/7] END .nb__alpha=0.9785536130829431;, score=0.802 total time=   0.9s
# [CV 1/5; 5/7] START nb__alpha=7.525474603916969.................................
# [CV 1/5; 5/7] END ..nb__alpha=7.525474603916969;, score=0.685 total time=   0.8s
# [CV 2/5; 5/7] START nb__alpha=7.525474603916969.................................
# [CV 2/5; 5/7] END ..nb__alpha=7.525474603916969;, score=0.668 total time=   0.8s
# [CV 3/5; 5/7] START nb__alpha=7.525474603916969.................................
# [CV 3/5; 5/7] END ..nb__alpha=7.525474603916969;, score=0.675 total time=   0.8s
# [CV 4/5; 5/7] START nb__alpha=7.525474603916969.................................
# [CV 4/5; 5/7] END ..nb__alpha=7.525474603916969;, score=0.655 total time=   0.8s
# [CV 5/5; 5/7] START nb__alpha=7.525474603916969.................................
# [CV 5/5; 5/7] END ..nb__alpha=7.525474603916969;, score=0.688 total time=   1.2s
# [CV 1/5; 6/7] START nb__alpha=4.935681438981289.................................
# [CV 1/5; 6/7] END ..nb__alpha=4.935681438981289;, score=0.725 total time=   1.4s
# [CV 2/5; 6/7] START nb__alpha=4.935681438981289.................................
# [CV 2/5; 6/7] END ..nb__alpha=4.935681438981289;, score=0.727 total time=   0.9s
# [CV 3/5; 6/7] START nb__alpha=4.935681438981289.................................
# [CV 3/5; 6/7] END ..nb__alpha=4.935681438981289;, score=0.718 total time=   0.8s
# [CV 4/5; 6/7] START nb__alpha=4.935681438981289.................................
# [CV 4/5; 6/7] END ..nb__alpha=4.935681438981289;, score=0.690 total time=   0.8s
# [CV 5/5; 6/7] START nb__alpha=4.935681438981289.................................
# [CV 5/5; 6/7] END ..nb__alpha=4.935681438981289;, score=0.730 total time=   0.9s
# [CV 1/5; 7/7] START nb__alpha=3.4278930220512294................................
# [CV 1/5; 7/7] END .nb__alpha=3.4278930220512294;, score=0.748 total time=   0.9s
# [CV 2/5; 7/7] START nb__alpha=3.4278930220512294................................
# [CV 2/5; 7/7] END .nb__alpha=3.4278930220512294;, score=0.758 total time=   0.8s
# [CV 3/5; 7/7] START nb__alpha=3.4278930220512294................................
# [CV 3/5; 7/7] END .nb__alpha=3.4278930220512294;, score=0.745 total time=   0.9s
# [CV 4/5; 7/7] START nb__alpha=3.4278930220512294................................
# [CV 4/5; 7/7] END .nb__alpha=3.4278930220512294;, score=0.727 total time=   0.9s
# [CV 5/5; 7/7] START nb__alpha=3.4278930220512294................................
# [CV 5/5; 7/7] END .nb__alpha=3.4278930220512294;, score=0.763 total time=   0.9s
# RandomizedSearchCV(estimator=Pipeline(steps=[('tfidf',
#                                               TfidfVectorizer(stop_words='english')),
#                                              ('nb', MultinomialNB())]),
#                    n_iter=7,
#                    param_distributions={'nb__alpha': <scipy.stats._distn_infrastructure.rv_continuous_frozen object at 0x7da5de7600b0>},
#                    verbose=100)

# %%
ypred=clf.predict(Xtest)
print(classification_report(ytest,ypred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.67      0.38      0.48        21
#            1       0.79      0.52      0.63        21
#            2       0.58      0.69      0.63        26
#            3       0.72      0.68      0.70        34
#            4       0.74      0.85      0.79        34
#            5       0.88      0.81      0.84        26
#            6       1.00      0.73      0.84        22
#            7       0.70      1.00      0.82        28
#            8       0.90      0.82      0.86        33
#            9       0.88      0.84      0.86        25
#           10       0.82      1.00      0.90        27
#           11       0.79      0.95      0.86        20
#           12       0.59      0.54      0.57        24
#           13       0.75      0.78      0.77        23
#           14       0.87      0.71      0.78        28
#           15       0.53      0.90      0.67        29
#           16       0.50      0.95      0.66        21
#           17       0.94      0.83      0.88        18
#           18       0.86      0.23      0.36        26
#           19       0.00      0.00      0.00        14
#
#     accuracy                           0.73       500
#    macro avg       0.72      0.71      0.70       500
# weighted avg       0.74      0.73      0.71       500
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %% [markdown]
# #### Exercise
#
# 1. For the Naive Bayes model, use grid search 5-fold cross-validation across different values of `alpha` to find the best model.
#
# 2. For the best value of `alpha`, compute the `f1_macro` score on the test set.
# * What value of `alpha` did you obtain?
# * What is the model's `f1_macro` score?
#
# 3. Repeat Exercise 1 and 2 for **random search** 5-fold cross validation across different values of `alpha`. Compute the `f1_macro` score on the test set.
# * What value of `alpha` did you obtain?
# * Did you get a better `f1_macro` score compared to grid search in Exercise 2?

# %% [markdown]
# What value of alpha did you obtain?
#
# **Answer** 1.86412775432509
#
# What is the model's f1_macro score?
#
# **Answer** 0.6738511205930988

# %% [markdown]
# What value of alpha did you obtain?
#
# **Answer** 0.5384105420633545
#
# Did you get a better f1_macro score compared to grid search in Exercise 2?
#
# **Answer** 0.7109502254002459 ได้ค่าที่ดีกว่า

# %%
parameters={'nb__alpha': uniform(loc=0, scale=10)}
clf=RandomizedSearchCV(pipeline,parameters,scoring='f1_macro',cv=5)
                          # ,n_iter=50,random_state=42)
clf.fit(Xtrain, ytrain)
# Out:
# RandomizedSearchCV(cv=5,
#                    estimator=Pipeline(steps=[('tfidf',
#                                               TfidfVectorizer(stop_words='english')),
#                                              ('nb', MultinomialNB())]),
#                    param_distributions={'nb__alpha': <scipy.stats._distn_infrastructure.rv_continuous_frozen object at 0x7d0439ea2720>},
#                    scoring='f1_macro')

# %%
best_params=clf.best_params_
print(clf.best_params_['nb__alpha'])
# Out:
# 0.5384105420633545

# %%
ypred=clf.predict(Xtest)
print(classification_report(ytest,ypred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.69      0.43      0.53        21
#            1       0.72      0.62      0.67        21
#            2       0.60      0.69      0.64        26
#            3       0.73      0.71      0.72        34
#            4       0.78      0.85      0.82        34
#            5       0.90      0.69      0.78        26
#            6       1.00      0.73      0.84        22
#            7       0.70      1.00      0.82        28
#            8       0.90      0.82      0.86        33
#            9       0.92      0.88      0.90        25
#           10       0.84      1.00      0.92        27
#           11       0.76      0.95      0.84        20
#           12       0.61      0.58      0.60        24
#           13       0.82      0.78      0.80        23
#           14       0.88      0.82      0.85        28
#           15       0.54      0.90      0.68        29
#           16       0.51      0.95      0.67        21
#           17       0.94      0.83      0.88        18
#           18       0.88      0.27      0.41        26
#           19       0.00      0.00      0.00        14
#
#     accuracy                           0.75       500
#    macro avg       0.74      0.73      0.71       500
# weighted avg       0.75      0.75      0.73       500
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
from sklearn.metrics import f1_score, classification_report

f1_macro_test=f1_score(ytest, ypred, average='macro')
print(f1_macro_test)
# Out:
# 0.7109502254002459
